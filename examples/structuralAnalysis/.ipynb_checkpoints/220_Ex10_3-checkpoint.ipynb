# %%
import ema as em
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# # Example 10.3
#
# (Page 267 of CE-220 Fall 2019 course reader)

# %%
dm = em.rModel(2,3)
A = 100000
I = 60
dm.xsection('default',A,I)
dm.material('default', 1000)

n1 = dm.node('1',  0.0,  2.0)
n2 = dm.node('2',  0.0, 10.0)
n3 = dm.node('3', 10.0, 10.0)
n4 = dm.node('4', 20.0, 10.0)
n5 = dm.node('5', 20.0,  0.0)

a = dm.beam('a', n1,  n2)
b = dm.beam('b', n2,  n3)
c = dm.beam('c', n3,  n4)
d = dm.beam('d', n4,  n5)

dm.hinge(a, n1)

a.w['y'] = -5
b.w['y'] = -10

dm.fix(n1, ['x', 'y', 'rz'])
dm.fix(n5, ['x', 'y', 'rz'])

dm.DOF = [[6, 7, 8],[1, 7, 2], [1, 3, 4], [1, 9, 5], [10, 9, 11]]

# %%
fig, ax = plt.subplots()
em.plot_structure(dm, ax)

# %% [markdown]
# ## Part 1
#
# Determine the basic forces in all elements.

# %%
B = em.B_matrix(dm)
P = em.P_vector(B)
P.wf
# Out:
# P_vector([-20.,   0.,  50.,   0.,   0.])

# %%
Q0 = em.Q_vector(B).o
Q0
# Out:
# Q_vector([ -0.        ,   0.        , -40.        ,  -0.        ,
#            83.33333333, -83.33333333,  -0.        ,   0.        ,
#             0.        ,  -0.        ,   0.        ,   0.        ])

# %%
assert abs(Q0.get('a_3') - -40.000000000) < 10e-8
assert abs(Q0.get('b_2') -  83.333333333) < 10e-8
assert abs(Q0.get('b_3') - -83.333333333) < 10e-8

# %%
P0 = B.f@Q0 + P.wf
P0
# Out:
# P_vector([-25.        ,  43.33333333,  50.        , -83.33333333,
#             0.        ])

# %%
assert abs(P0.get('1') - -25) < 10e-8
assert abs(P0.get('2') -  43.33333333333) < 10e-8
assert abs(P0.get('3') -  50) < 10e-8
assert abs(P0.get('4') - -83.33333333333) < 10e-8

# %%
Uf = em.analysis.SolveDispl(dm)
Uf
# Out:
# Displacement_vector([ 0.04991421, -0.00946158, -0.05707374,  0.00423175,
#                      -0.00052097])

# %%
Qi = B.bari@(P.f - P.wf)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-10-fc8d32278c05> in <module>
# ----> 1 Qi = B.bari@(P.f - P.wf)
#
# ~\OneDrive\400_box\Python\myPackages\ema\matvecs.py in bari(self)
#     210     @property
#     211     def bari(self):
# --> 212         return self.i.del_zeros().inv
#     213
#     214     @property
#
# ~\OneDrive\400_box\Python\myPackages\ema\utilities\__init__.py in inv(self)
#     152     @property
#     153     def inv(self):
# --> 154         mat = np.linalg.inv(self)
#     155         transfer_vars(self, mat)
#     156         mat.row_data = self.column_data
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in inv(a)
#     544     a, wrap = _makearray(a)
#     545     _assertRankAtLeast2(a)
# --> 546     _assertNdSquareness(a)
#     547     t, result_t = _commonType(a)
#     548
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _assertNdSquareness(*arrays)
#     211         m, n = a.shape[-2:]
#     212         if m != n:
# --> 213             raise LinAlgError('Last 2 dimensions of the array must be square')
#     214
#     215 def _assertFinite(*arrays):
#
# LinAlgError: Last 2 dimensions of the array must be square

# %%
Qi.df

# %%
Q = em.Q_vector(B,Qi)

# %% [markdown]
# ## Part 2
#
# Determine the horizontal and vertical translation at node 3.

# %%
A = em.A_matrix(dm).add_cols(['1', '5']).add_cols(['3', '6']).remove(['7']).remove(['8']).remove('frame-axial')
V = em.V_vector(A)
A.c.df

# %%
F = em.F_matrix(dm)
F.s

# %%
V = F.s@Q
V

# %%
Uf = A.c.inv@V.c
Uf.df
