# %% [markdown]
# # Problem 18

# %%
import ema as em
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'

# %%
mdl = em.Model(2,3)
n = mdl.dnodes
e = mdl.delems

mdl.xsection('default', 1e10, 50000)
xt = mdl.xsection('truss', 50e3, 1)

mdl.node('1',  0.0, 0.0)
mdl.node('2',  6.0, 8.0)
mdl.node('3', 12.0, 8.0)
mdl.node('4', 12.0, 0.0)

mdl.beam('a', n['2'], n['3'])
mdl.beam('b', n['3'], n['4'])
mdl.truss('c', n['1'], n['2'], xsec=xt)

# mdl.hinge(e['a'], n['2'])

mdl.fix(n['1'], ['x','y', 'rz'])
# mdl.fix(n['2'], ['rz'])
mdl.fix(n['4'], ['x','y', 'rz'])

mdl.numDOF()
# Out:
# [[7, 8, 9], [1, 2, 3], [4, 5, 6], [10, 11, 12]]

# %% [markdown]
# The loading is next defined, as follows:

# %%
# Define loading
n['2'].p['x']  = -50
e['a'].e0['2'] = -1e-3
e['b'].e0['2'] =  1e-3
e['c'].q0['1'] =  50.183
# em.utilities.export.FEDEAS(mdl)

# %% [markdown]
# ## Part 1: Degree of indeterminacy

# %%
em.analysis.characterize(mdl)
# Out:
# (0, 1)

# %%
fig, ax = plt.subplots(1,1)
em.plot_structure(mdl, ax)
U_disp = em.analysis.SolveDispl(mdl) 
em.plot_U(mdl, U_disp, ax, scale=100)

# %%
U_disp
# Out:
# Displacement_vector([-3.18964260e-02,  6.16317777e-03, -2.91365037e-05,
#                      -3.18964035e-02,  1.33462829e-08, -2.33092036e-05])

# %% [markdown]
# ## Part 3: Find member forces

# %%
B = em.B_matrix(mdl)
A = em.A_matrix(mdl)
V = A.f@U_disp
V
# Out:
# Deformation_vector([ 2.24927159e-08,  9.98057567e-04,  1.00388487e-03,
#                      1.33462829e-08, -4.01035965e-03, -3.98705044e-03,
#                     -1.42073134e-02])

# %%
Ks = em.K_matrix(mdl).s
Q0 = em.Q_vector(B).o
Q = Ks@V + Q0
Q
# Out:
# Structural_Vector([ 3.74878598e+01, -2.84217094e-14,  1.00097122e+02,
#                     1.66828536e+01, -1.00097122e+02, -1.99805757e+02,
#                    -2.08535670e+01])
