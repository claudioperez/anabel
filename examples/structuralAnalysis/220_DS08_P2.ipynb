# %%
import ema as em
import matplotlib.pyplot as plt
import numpy as np
# %config InlineBackend.figure_format = 'svg'

# %%
dm = em.Domain(2,3)
e = dm.delems
n = dm.dnodes
dm.frame([1,20],[3,10])

# %%
fig, ax = plt.subplots()
em.plot_structure(dm, ax)
