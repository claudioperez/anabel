# %% [markdown]
# # Problem 2

# %%
import ema as em
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'

# %%
#Remove
mdl = em.Model(2,3)
n = mdl.dnodes
e = mdl.delems

mdl.node('1',  0.0, 0.0)
mdl.node('2',  8.0, 0.0)
mdl.node('3', 16.0, 0.0)
mdl.node('4',  8.0, 6.0)
mdl.node('5', 16.0, 6.0)

mdl.beam('a', n['1'], n['2'])
mdl.beam('b', n['2'], n['4'])
mdl.beam('c', n['4'], n['5'])
mdl.truss('d', n['1'], n['4'])
mdl.truss('e', n['3'], n['4'])

mdl.fix(n['1'], ['x','y', 'rz'])
mdl.fix(n['3'], ['x','y', 'rz'])
mdl.fix(n['5'], ['y'])

e['a'].w['y'] = -10
e['b'].w['y'] = -10
mdl.numDOF()
# Out:
# [[9, 10, 11], [1, 2, 3], [12, 13, 14], [4, 5, 6], [7, 15, 8]]

# %% [markdown]
# ## Part 1: Degree of indeterminacy

# %%
em.analysis.characterize(mdl)
# Out:
# (0, 3)

# %%
fig, ax = plt.subplots(1,1)
em.plot_structure(mdl, ax)
# U_disp = em.analysis.SolveDispl(mdl) 
# em.plot_U(mdl, U_disp, ax, scale=100)

# %%
mdl.redundant(e['c'], '2')
mdl.redundant(e['d'], '1')
mdl.redundant(e['e'], '1')

# %%
B = em.B_matrix(mdl)
B.barx
# Out:
# Structural_Matrix([[ 0.0000000e+00, -8.0000000e-01,  8.0000000e-01],
#                    [ 2.0000000e+00, -8.8817842e-16,  9.6000000e+00],
#                    [-1.0000000e+00,  4.8000000e+00, -4.8000000e+00],
#                    [-1.2500000e-01, -6.0000000e-01, -6.0000000e-01],
#                    [ 1.0000000e+00, -4.8000000e+00,  4.8000000e+00],
#                    [-1.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#                    [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#                    [ 1.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#                    [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#                    [ 0.0000000e+00,  1.0000000e+00,  0.0000000e+00],
#                    [ 0.0000000e+00,  0.0000000e+00,  1.0000000e+00]])
