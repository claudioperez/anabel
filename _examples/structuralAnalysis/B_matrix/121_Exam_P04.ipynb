# %% [markdown]
# # Problem 4

# %%
import ema as em
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'

# %%
#Remove
mdl = em.rModel(2,3)
n = mdl.dnodes
e = mdl.delems

mdl.material('default', 1000)
mdl.xsection('default', 10000000000, 50)
xt = mdl.xsection('truss', 20, 1)

mdl.node('1',  0.0, 0.0)
mdl.node('2',  8.0, 0.0)
mdl.node('3', 16.0, 0.0)
mdl.node('4',  8.0, 6.0)

mdl.beam('a', n['1'], n['2'])
mdl.beam('b', n['2'], n['3'])
mdl.beam('c', n['2'], n['4'])
mdl.truss('d', n['3'], n['4'], xsec=xt)



mdl.fix(n['1'], ['y'])
mdl.fix(n['3'], ['x', 'y', 'rz'])

mdl.numDOF()
# Out:
# [[1, 9, 2], [3, 4, 5], [10, 11, 12], [6, 7, 8]]

# %%
fig, ax = plt.subplots(1,1)
em.plot_structure(mdl, ax)

# %%
mdl.redundant(e['d'], '1')
mdl.redundant(e['b'], '2')
B = em.B_matrix(mdl)
B.barx
# Out:
# Structural_Matrix([[ 0. ,  0. ],
#                    [ 0. ,  0. ],
#                    [-4.8, -1. ],
#                    [-0.8,  0. ],
#                    [ 0. ,  1. ],
#                    [-9.6, -2. ],
#                    [-0.6,  0. ],
#                    [ 4.8,  0. ],
#                    [ 0. ,  0. ],
#                    [ 1. ,  0. ]])

# %%
Q = em.column_vector(B)
A = em.A_matrix(mdl)
Vi = em.V_vector(A)

k0 = -0.002014
DL =  0.033333
e['a'].e0['2'] = -k0
e['a'].e0['3'] = -k0
e['b'].e0['2'] =  k0
e['b'].e0['3'] =  k0
e['d'].e0['1'] =  DL/e['d'].L

# %%
Q0 = em.Q_vector(B).o
Q0
# Out:
# Q_vector([  -0.   ,  100.7  , -100.7  ,   -0.   , -100.7  ,  100.7  ,
#             -0.   ,    0.   ,    0.   ,  -66.666])

# %%
Uf = em.analysis.SolveDispl(mdl)
K = em.K_matrix(mdl)
U = em.U_vector(A, Uf)
V = A.f@Uf
Q = K.s@V + Q0
Q
# Out:
# Structural_Vector([ 0.00000000e+00,  0.00000000e+00,  4.60131452e+01,
#                     5.50043210e+00, -1.30105526e+01,  9.20262999e+01,
#                     4.12531699e+00, -3.30025926e+01,  2.13162821e-14,
#                    -6.87554012e+00])

# %% [markdown]
# ## Part 1

# %%
K = em.K_matrix(mdl)
K.f
# Out:
# Stiffness_matrix([[ 1.25000000e+12,  0.00000000e+00, -1.25000000e+12,
#                     0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#                     0.00000000e+00,  0.00000000e+00],
#                   [ 0.00000000e+00,  2.50000000e+04,  0.00000000e+00,
#                    -4.68750000e+03,  1.25000000e+04,  0.00000000e+00,
#                     0.00000000e+00,  0.00000000e+00],
#                   [-1.25000000e+12,  0.00000000e+00,  2.50000000e+12,
#                     0.00000000e+00, -8.33333333e+03, -2.77777778e+03,
#                     0.00000000e+00, -8.33333333e+03],
#                   [ 0.00000000e+00, -4.68750000e+03,  0.00000000e+00,
#                     1.66666667e+12,  0.00000000e+00,  0.00000000e+00,
#                    -1.66666667e+12,  0.00000000e+00],
#                   [ 0.00000000e+00,  1.25000000e+04, -8.33333333e+03,
#                     0.00000000e+00,  8.33333333e+04,  8.33333333e+03,
#                     0.00000000e+00,  1.66666667e+04],
#                   [ 0.00000000e+00,  0.00000000e+00, -2.77777778e+03,
#                     0.00000000e+00,  8.33333333e+03,  4.05777778e+03,
#                    -9.60000000e+02,  8.33333333e+03],
#                   [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#                    -1.66666667e+12,  0.00000000e+00, -9.60000000e+02,
#                     1.66666667e+12,  0.00000000e+00],
#                   [ 0.00000000e+00,  0.00000000e+00, -8.33333333e+03,
#                     0.00000000e+00,  1.66666667e+04,  8.33333333e+03,
#                     0.00000000e+00,  3.33333333e+04]])

# %%
UK = K.f.inv@[0, 6250, -100000, 50000]
UK
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-a79df1636cdf> in <module>
# ----> 1 UK = K.f.inv@[0, 6250, -100000, 50000]
#       2 UK
#
# ~\OneDrive\400_box\Python\myPackages\ema\matvecs.py in __matmul__(self, Vector)
#     690             vect.matrix = self
#     691         else:
# --> 692             vect = Structural_Matrix.__matmul__(self, Vector)
#     693         return vect
#     694
#
# ~\OneDrive\400_box\Python\myPackages\ema\utilities\__init__.py in __matmul__(self, other)
#     130             # out.column_data = ['.']
#     131         else:
# --> 132             out = np.matmul(self,other).view(Structural_Vector)
#     133             out.row_data = self.row_data
#     134             # out.column_data = ['.']
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 4 is different from 8)

# %%
UL = K.f.inv@[1600, 1200., 0., 0.]
UL

# %%
# Q.set_item('a_2', 87.947)
# Q.set_item('a_3', 54.824)
# Q.set_item('b_2',-54.824)
# Q.set_item('b_3', 22.844)
# Q.set_item('c_2',-22.844)
# Q.set_item('d_1', 15.497)
