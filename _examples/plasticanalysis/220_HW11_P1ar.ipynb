# %%
import ema as em
import matplotlib.pyplot as plt
import numpy as np
# %config InlineBackend.figure_format = 'svg' # used to make plots look nicerbb

# %% [markdown]
# # Problem 3

# %%
#Remove
mdl = em.rModel(2,3)
n = mdl.dnodes
e = mdl.delems

mdl.node('1',  0.0, 0.0)
mdl.node('2',  8.0, 0.0)
mdl.node('3',  8.0, 6.0)
mdl.node('4', 16.0, 6.0)

mdl.beam('a', n['1'], n['2'])
mdl.beam('b', n['2'], n['3'])
mdl.beam('c', n['3'], n['4'])

mdl.hinge(e['a'], n['1'])
mdl.hinge(e['a'], n['2'])
mdl.hinge(e['b'], n['2'])
mdl.hinge(e['c'], n['4'])

mdl.fix(n['1'], ['x', 'y', 'rz'])
mdl.fix(n['2'], ['rz'])
mdl.fix(n['4'], ['y', 'rz'])

# mdl.numDOF()
mdl.DOF = [[4, 5, 6], [4, 1, 7], [2, 1, 3], [2, 8, 9]]

# %%
fig, ax = plt.subplots()
em.plot_structure(mdl, ax)

# %%
A = em.A_matrix(mdl).remove('frame-axial')
A.c
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e6995e51b310> in <module>
# ----> 1 A = em.A_matrix(mdl).remove('frame-axial')
#       2 A.c
#
# ~\OneDrive\400_box\Python\myPackages\ema\matrices.py in remove(self, component)
#     295                 # except: pass
#     296             else:
# --> 297                 delrow = self.row_data.index(item)
#     298                 newM = np.delete(self, delrow, axis=0).view(type(self))
#     299                 newM.column_data = self.column_data
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
ker = A.c.ker 
A_cm = ker/ker[0]
A_cm

# %%
em.plot_U(mdl, ker, ax, scale=0.5)

# %% [markdown]
# ## Part 3

# %%
A.f

# %%
A.f@A_cm
