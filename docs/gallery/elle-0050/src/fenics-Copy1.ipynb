# %%
from dolfin import *
from mshr import *

xmin = 0.0
xmax = 2.2
ymin = 0.0
ymax = 0.41

xcenter = 0.2
ycenter = 0.2
radius = 0.05

domain = Rectangle(Point(xmin,ymin),Point(xmax,ymax)) - Circle(Point(xcenter,ycenter),radius,12)

mesh = generate_mesh(domain,20)
plot(mesh)

# %%
# !conda install mshr --yes
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/claudio/miniconda3/envs/elle
#
#   added / updated specs:
#     - mshr
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mshr-2019.1.0              |   py38h255090a_2         2.2 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   mshr               conda-forge/linux-64::mshr-2019.1.0-py38h255090a_2
#
#
#
# ...
# mshr-2019.1.0        | 2.2 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9063a9f0e032> in <module>
# ----> 1 y
#
# NameError: name 'y' is not defined
