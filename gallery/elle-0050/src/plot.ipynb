# %%
import anabel
import anabel.backend as anp

# %% [markdown]
# ## Analytic Solution

# %%
# pblm = ""

# def u(x):
#     x = x.flatten()
#     return 1-x[0]**2 - x[1]**2

# f=lambda x: 4.0

# %%
PI = anp.pi
u = lambda x: anp.cos(PI/2*anp.linalg.norm(x))
f = lambda x: PI**2/4*(anp.cos(PI*anp.linalg.norm(x)/2)+anp.sinc(PI*anp.linalg.norm(x)/2))

# %%
model = anabel.MeshGroup.read(f"circle_iso/mesh4", "m228", cell="triangle6")
model.plot(func=u, savefig="../img/analytic-b.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FB389168D30>

# %% [markdown]
# ## FEM Solution

# %%
m, g = 1,19
pblm = "-b"
model = anabel.MeshGroup.read(f"circle_iso/mesh{m}","m228",cell="triangle6")

# %%
Uh = anp.load(f"mesh{m}-gauss{g:02}{pblm}.npz")["arr_0"]

# %%
model.plot(Uh,savefig=f"../img/mesh{m}-gauss{g:02}{pblm}.npz")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-53be29bff90c> in <module>
# ----> 1 model.plot(Uh,savefig=f"../img/mesh{m}-gauss{g:02}{pblm}.npz")
#
# ~/pkgs/anabel/src/anabel/assemble.py in plot(self, values, func, interact, savefig, **kwds)
#     304                        point_size=5, render_points_as_spheres=True)
#     305                 if savefig:
# --> 306                     plotter.show(screenshot=savefig)
#     307                 else:
#     308                     plotter.show()
#
# ~/miniconda3/envs/elle/lib/python3.8/site-packages/pyvista/plotting/plotting.py in show(self, title, window_size, interactive, auto_close, interactive_update, full_screen, screenshot, return_img, cpos, use_ipyvtk, **kwargs)
#    4378         if pyvista.BUILDING_GALLERY or screenshot:
#    4379             # always save screenshots for sphinx_gallery
# ...
